# %%
# 一、获取股票基础信息数据
# 1.上证和深证股票
import baostock as bs
import pandas as pd
import sys
import StockBackProgram
import importlib

from StockBackProgram import *

# 更改 StockBackProgram.py 后
importlib.reload(StockBackProgram)

print(sys.executable)  # 查看当前Python解释器的路径
print(12)
trade_date = "2024-01-02";
# Out:
# /opt/anaconda3/bin/python
# 12

# %%
trade_date_file_name = "trade_date_2024.csv"
start_date = "2024-01-01"
end_date ="2024-01-10"
## 下载交易日期，0不是，1是
download_trade_date(trade_date_file_name,start_date,end_date)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_trade_dates respond error_code:0
# query_trade_dates respond  error_msg:success
#   calendar_date is_trading_day
# 0    2024-01-01              0
# 1    2024-01-02              1
# 2    2024-01-03              1
# 3    2024-01-04              1
# 4    2024-01-05              1
# 5    2024-01-06              0
# 6    2024-01-07              0
# 7    2024-01-08              1
# 8    2024-01-09              1
# 9    2024-01-10              1
# logout success!

# %%
## 获取某日所有证券信息,第一个参数交易文件交易日期默认从这文件里取第一个交易日期，第二个参数交易日期如果给了优先用这个
all_stocks_file = "stock_file_20240102.csv"
download_all_stocks_by_day(trade_date_file_name,"2024-01-02",all_stocks_file)
# Out:
# trade_date_2024.csv
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_all_stock respond error_code:0
# query_all_stock respond  error_msg:success
#            code tradeStatus   code_name
# 0     sh.000001           1      上证综合指数
# 1     sh.000002           1      上证A股指数
# 2     sh.000003           1      上证B股指数
# 3     sh.000004           1     上证工业类指数
# 4     sh.000005           1     上证商业类指数
# ...         ...         ...         ...
# 5633  sz.399994           1  中证信息安全主题指数
# 5634  sz.399995           1    中证基建工程指数
# 5635  sz.399996           1    中证智能家居指数
# 5636  sz.399997           1      中证白酒指数
# 5637  sz.399998           1      中证煤炭指数
#
# [5638 rows x 3 columns]
# logout success!

# %%
# 读取csv文件
df = read_csv(trade_date_file_name);
print(type(df))
print(df[df["is_trading_day"]==1])
print("第一个为交易日的日期："+df[df["is_trading_day"]==1].loc[1]["calendar_date"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
#   calendar_date  is_trading_day
# 1    2024-01-02               1
# 2    2024-01-03               1
# 3    2024-01-04               1
# 4    2024-01-05               1
# 7    2024-01-08               1
# 8    2024-01-09               1
# 9    2024-01-10               1
# 第一个为交易日的日期：2024-01-02

# %%
## 获取上证50
shz50_file = "stock_file_shz50.csv";
download_stocks_shz50(shz50_file,trade_date)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_sz50 error_code:0
# query_sz50  error_msg:success
#     updateDate       code code_name
# 0   2024-01-01  sh.600028      中国石化
# 1   2024-01-01  sh.600030      中信证券
# 2   2024-01-01  sh.600031      三一重工
# 3   2024-01-01  sh.600036      招商银行
# 4   2024-01-01  sh.600048      保利发展
# 5   2024-01-01  sh.600050      中国联通
# 6   2024-01-01  sh.600089      特变电工
# 7   2024-01-01  sh.600104      上汽集团
# 8   2024-01-01  sh.600111      北方稀土
# 9   2024-01-01  sh.600150      中国船舶
# 10  2024-01-01  sh.600276      恒瑞医药
# 11  2024-01-01  sh.600309      万华化学
# 12  2024-01-01  sh.600406      国电南瑞
# 13  2024-01-01  sh.600436       片仔癀
# 14  2024-01-01  sh.600438      通威股份
# 15  2024-01-01  sh.600519      贵州茅台
# 16  2024-01-01  sh.600690      海尔智家
# 17  2024-01-01  sh.600809      山西汾酒
# 18  2024-01-01  sh.600887      伊利股份
# 19  2024-01-01  sh.600893      航发动力
# 20  2024-01-01  sh.600900      长江电力
# ...

# %%
## 获取沪深300
hs300_file = "stock_file_hs300.csv";
download_stocks_shz50(hs300_file,trade_date)
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_sz50 error_code:0
# query_sz50  error_msg:success
#     updateDate       code code_name
# 0   2024-01-01  sh.600028      中国石化
# 1   2024-01-01  sh.600030      中信证券
# 2   2024-01-01  sh.600031      三一重工
# 3   2024-01-01  sh.600036      招商银行
# 4   2024-01-01  sh.600048      保利发展
# 5   2024-01-01  sh.600050      中国联通
# 6   2024-01-01  sh.600089      特变电工
# 7   2024-01-01  sh.600104      上汽集团
# 8   2024-01-01  sh.600111      北方稀土
# 9   2024-01-01  sh.600150      中国船舶
# 10  2024-01-01  sh.600276      恒瑞医药
# 11  2024-01-01  sh.600309      万华化学
# 12  2024-01-01  sh.600406      国电南瑞
# 13  2024-01-01  sh.600436       片仔癀
# 14  2024-01-01  sh.600438      通威股份
# 15  2024-01-01  sh.600519      贵州茅台
# 16  2024-01-01  sh.600690      海尔智家
# 17  2024-01-01  sh.600809      山西汾酒
# 18  2024-01-01  sh.600887      伊利股份
# 19  2024-01-01  sh.600893      航发动力
# 20  2024-01-01  sh.600900      长江电力
# ...

# %%
## 获取股票行业分类数据
stock_industry_file = "stock_file_industry.csv"
download_stock_industry(stock_industry_file,trade_date);
# Out:
# login success!
# login respond error_code:0
# login respond  error_msg:success
# query_stock_industry error_code:0
# query_stock_industry respond  error_msg:success
#       updateDate       code code_name             industry  \
# 0     2024-01-01  sh.600000      浦发银行            J66货币金融服务
# 1     2024-01-01  sh.600001      邯郸钢铁
# 2     2024-01-01  sh.600002      齐鲁石化
# 3     2024-01-01  sh.600003     ST东北高
# 4     2024-01-01  sh.600004      白云机场             G56航空运输业
# ...          ...        ...       ...                  ...
# 5325  2024-01-01  sz.301558      三态股份               F52零售业
# 5326  2024-01-01  sz.301559      中集环科           C34通用设备制造业
# 5327  2024-01-01  sz.301566      达利凯普  C39计算机、通信和其他电子设备制造业
# 5328  2024-01-01  sz.301568       思泰克           C35专用设备制造业
# 5329  2024-01-01  sz.301578      辰奕智能  C39计算机、通信和其他电子设备制造业
#
#      industryClassification
# 0                   证监会行业分类
# 1                   证监会行业分类
# 2                   证监会行业分类
# 3                   证监会行业分类
# ...

# %%
## 获以股票基本信息，只拿沪深300的
